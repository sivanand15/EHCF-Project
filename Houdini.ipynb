# %%
from PyQt5.QtWidgets import *
from PyQt5 import *
from PyQt5.QtGui import *
from PyQt5.QtCore import QProcess
import sys

class Widgets(QWidget):
    def __init__(self,**kwargs):
        super(Widgets,self).__init__()
        
        self.setStyleSheet("background-color: black;")
        self.vlayout=QVBoxLayout()        
        
        self.l1 = QLabel("Houdini", self)
        self.vlayout.addWidget(self.l1)
        self.l1.setStyleSheet("border: 1px solid red; color: white")
        self.l1.setFont(QFont('gentona', 100))
        self.l1.move(450, 80)
        

        self.l2 = QLabel("The World of Steganography", self)
        self.vlayout.addWidget(self.l2)
        self.l2.setStyleSheet("color: red")
        self.l2.setFont(QFont('monotype corsiva', 20))
        self.l2.move(561, 232)
        

        self.b1= QPushButton("Image Steganography", self)
        self.vlayout.addWidget(self.b1)
        self.b1.setStyleSheet(" QPushButton{background-color:black;\
                                            color: white; border: 1px solid white; border-style: outset; padding :5px}" 
                              "QPushButton:hover{background-color:white; color: black;}"
                              "QPushButton:pressed{background-color:red; border-style: inset;}")
        self.b1.setFont(QFont('gentona', 18))
        self.b1.move(70, 310)
        self.b1.clicked.connect(self.on_click1)
        
        self.b2= QPushButton("Video Steganography", self)
        self.vlayout.addWidget(self.b2)
        self.b2.setStyleSheet(" QPushButton{background-color:black;\
                                            color: white; border: 1px solid white; border-style: outset; padding :5px}" 
                              "QPushButton:hover{background-color:white; color: black;}"
                              "QPushButton:pressed{background-color:red; border-style: inset;}")
        self.b2.setFont(QFont('gentona', 18))
        self.b2.move(320, 310)
        self.b2.clicked.connect(self.on_click2)
        
        self.b3= QPushButton("Audio Steganography", self)
        self.vlayout.addWidget(self.b3)
        self.b3.setStyleSheet(" QPushButton{background-color:black;\
                                            color: white; border: 1px solid white; border-style: outset; padding :5px}" 
                              "QPushButton:hover{background-color:white; color: black;}"
                              "QPushButton:pressed{background-color:red; border-style: inset;}")
        self.b3.setFont(QFont('gentona', 18))
        self.b3.move(560, 310)
        self.b3.clicked.connect(self.on_click3)
        
        self.b4= QPushButton("Text Steganography", self)
        self.vlayout.addWidget(self.b4)
        self.b4.setStyleSheet(" QPushButton{background-color:black;\
                                            color: white; border: 1px solid white; border-style: outset; padding :5px}" 
                              "QPushButton:hover{background-color:white; color: black;}"
                              "QPushButton:pressed{background-color:red; border-style: inset;}")
        self.b4.setFont(QFont('gentona', 18))
        self.b4.move(800, 310)
        self.b4.clicked.connect(self.on_click4)
        
        self.b5= QPushButton("Email Steganography", self)
        self.vlayout.addWidget(self.b5)
        self.b5.setStyleSheet(" QPushButton{background-color:black;\
                                            color: white; border: 1px solid white; border-style: outset; padding :5px}" 
                              "QPushButton:hover{background-color:white; color: black;}"
                              "QPushButton:pressed{background-color:red; border-style: inset;}")
        self.b5.setFont(QFont('gentona', 18))
        self.b5.move(1030, 310)
        self.b5.clicked.connect(self.on_click5)
        
        self.l6 = QLabel("Group members:", self)
        self.vlayout.addWidget(self.l6)
        self.l6.setStyleSheet("color: white")
        self.l6.setFont(QFont('monotype corsiva', 15))
        self.l6.move(1030, 410)
        
        self.l7 = QLabel("Deepika Nadimpally (20MTIS03)", self)
        self.vlayout.addWidget(self.l7)
        self.l7.setStyleSheet("color: white")
        self.l7.setFont(QFont('monotype corsiva', 15))
        self.l7.move(1030, 440)
        self.l8 = QLabel("Chintha Pooja (20MTIS04)", self)
        self.vlayout.addWidget(self.l8)
        self.l8.setStyleSheet("color: white")
        self.l8.setFont(QFont('monotype corsiva', 15))
        self.l8.move(1030, 465)
        self.l9 = QLabel("Akshara Alex (20MTIS09)", self)
        self.vlayout.addWidget(self.l9)
        self.l9.setStyleSheet("color: white")
        self.l9.setFont(QFont('monotype corsiva', 15))
        self.l9.move(1030, 490)
        self.l10 = QLabel("Hari Teja (20MTIS12)", self)
        self.vlayout.addWidget(self.l10)
        self.l10.setStyleSheet("color: white")
        self.l10.setFont(QFont('monotype corsiva', 15))
        self.l10.move(1030, 515)
        self.l11 = QLabel("Sivanand Sampara (20MTIS14)", self)
        self.vlayout.addWidget(self.l11)
        self.l11.setStyleSheet("color: white")
        self.l11.setFont(QFont('monotype corsiva', 15))
        self.l11.move(1030, 540)
        self.l12 = QLabel("Ankit Kumar (20MTIS16)", self)
        self.vlayout.addWidget(self.l12)
        self.l12.setStyleSheet("color: white")
        self.l12.setFont(QFont('monotype corsiva', 15))
        self.l12.move(1030, 565)
        
        
        
        self.setLayout=self.vlayout
        
        
    
    def on_click1(self):
        print("pressed 1") 
        call_process1()
        #https://www.mfitzp.com/tutorials/qprocess-external-programs/
        
        
    def on_click2(self):
        print("pressed 2")
    def on_click3(self):
        print("pressed 3")
    def on_click4(self):
        print("pressed 4")
    def on_click5(self):
        print("pressed 5")

def call_process1(self):
    self.message("Executing process.")
    self.p = QProcess()  # Keep a reference to the QProcess (e.g. on self) while it's running.
    self.p.start("python3", ['RunStartHere.py'])

def window():
    app=QApplication([])

    wig=Widgets()
    wig.setWindowTitle("Houdini")
    wig.show()
    app.exec_()

if __name__ == "__main__":
    window()
# Out:
# pressed 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-7c172eda9e7f> in on_click1(self)
#     121     def on_click1(self):
#     122         print("pressed 1")
# --> 123         call_process1()
#     124         #https://www.mfitzp.com/tutorials/qprocess-external-programs/
#     125
#
# TypeError: call_process1() missing 1 required positional argument: 'self'
